# %% [markdown]
# # FACE DETECTION

# %% [raw]
# THIS CODE IS FROM AN ALGORITHM CALLED VIOLA-JONES.
# THE MAIN FEATURE TYPES ARE
# LINE FEATURE
# FOUR RECTANGLE FEATURES
# FEATURES ARE CALCULATED BY AVERAGE OF DARK REGION MINUS AVERAGE OF LIGHT REGION.
# THE CLOSER THE RESULTS ARE TO 1 THE BETTER THE FEATURE
#
# THE VIOLA-JONES ALGORITHM USE THE INTEGRAL IMAGE AS A SUMMED AREA TABLE. THE ALGORITHM IS NOT SCANNING THE IMAGE.
# IT SEARCH FOR FEATURES LIKE EYES. IF THERE ARE NO EYES FEATURES NO FACE. THERE IS A CASCADE OF FEATURE TO CLASSIFY IF THERE IS A FACE.
# SECOND FEATURE IS THE NOSE AND SO ON.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
nadia = cv2.imread('data/Nadia_Murad.jpg',0)
denis = cv2.imread('data/Denis_Mukwege.jpg',0)
solvay = cv2.imread('data/solvay_conference.jpg',0)
role = cv2.imread('data/role.jpg',0)

# %%
plt.imshow(role,cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('data/haarcascades/haarcascade_frontalface_default.xml')

# %%
def detect_face(img):
    
    face_img = img.copy()
    
    face_rects = face_cascade.detectMultiScale(face_img)
    
    for (x,y,w,h) in face_rects:
        cv2.rectangle(face_img,(x,y),(x+w,y+h),(255,255,255),10)
        
    return face_img

# %%
result = detect_face(role)

# %%
plt.imshow(result,cmap='gray')

# %%
def adj_detect_face(img):
    
    face_img = img.copy()
    
    face_rects = face_cascade.detectMultiScale(face_img,scaleFactor=1.2,minNeighbors=5)
    
    for (x,y,w,h) in face_rects:
        cv2.rectangle(face_img,(x,y),(x+w,y+h),(255,255,255),10)
        
    return face_img

# %%
result = adj_detect_face(role)
plt.imshow(result,cmap='gray')

# %%
eye_cascade = cv2.CascadeClassifier('data/haarcascades/haarcascade_eye.xml')

# %%
def detect_eyes(img):
    
    face_img = img.copy()
    
    eyes_rects = eye_cascade.detectMultiScale(face_img)
    
    for (x,y,w,h) in eyes_rects:
        cv2.rectangle(face_img,(x,y),(x+w,y+h),(255,255,255),10)
        
    return face_img

# %%
result = detect_eyes(role)
plt.imshow(result,cmap='gray')

# %%
# let's do this now with a video

cap = cv2.VideoCapture(0)

while True:
    
     ret,frame = cap.read(0)
    
     frame = detect_face(frame)
    
     frame = detect_eyes(frame)
    
     cv2.imshow('Video Face Detect',frame)
    
     k = cv2.waitKey(1)
    
     if k == 27:
         break
        

cap.realease()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-a82f7cd365e5> in <module>
#       7      ret,frame = cap.read(0)
#       8
# ----> 9      frame = detect_face(frame)
#      10
#      11      frame = detect_eyes(frame)
#
# <ipython-input-38-45fffc3cd929> in detect_face(img)
#       1 def detect_face(img):
#       2
# ----> 3     face_img = img.copy()
#       4
#       5     face_rects = face_cascade.detectMultiScale(face_img)
#
# AttributeError: 'NoneType' object has no attribute 'copy'
